# %%
import json
from collections import defaultdict

# %%
original = json.loads(open('private_draft_data.json').read())

# %%
original[0]
# Out:
# {'name': 'quicklime',
#  'season': '4',
#  'week': '3',
#  'venue': 'Pub',
#  'type': 'pick',
#  'gametype': 'a4/7',
#  'guests': '16',
#  'starttime': '0',
#  'games': '2'}

# %%
sorted(original, key=lambda x: (x["name"], x["week"], x["games"]))
# Out:
# [{'name': 'anorexicwhale',
#   'season': '4',
#   'week': '3',
#   'venue': 'Old Gallery',
#   'type': 'ban',
#   'gametype': 'a4/8',
#   'guests': '0',
#   'starttime': '0',
#   'games': '0'},
#  {'name': 'anorexicwhale',
#   'season': '4',
#   'week': '3',
#   'venue': 'Old Gallery',
#   'type': 'ban',
#   'gametype': 'a4/7',
#   'guests': '0',
#   'starttime': '0',
#   'games': '0'},
#  {'name': 'anorexicwhale',
#   'season': '4',
#   'week': '3',
#   'venue': 'Old Gallery',
#   'type': 'ban',
#   'gametype': 'a4/8',
#   'guests': '0',
#   'starttime': '0',
#   'games': '0'},
#  {'name': 'anorexicwhale',
#   'season': '4',
#   'week': '3',
#   'venue': 'Old Gallery',
#   'type': 'ban',
#   'gametype': 'a4/7',
#   'guests': '0',
#   'starttime': '0',
#   'games': '0'},
#  {'name': 'anorexicwhale',
#   'season': '4',
#   'week': '3',
#   'venue': 'Old Gallery',
#   'type': 'ban',
#   'gametype': 'a4/8',
#   'guests': '0',
#   'starttime': '0',
#   'games': '0'},
# ...

# %%
new = []
name = None
for o in original:
