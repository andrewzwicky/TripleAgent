# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..\..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.constants.events import select_sc19
from triple_agent.reports.specific.character_selection import (spy_selection,
                                                      st_selection,
                                                      amba_selection,
                                                      double_agent_selection,
                                                      determine_character_in_role)
from triple_agent.reports.specific.game_outcomes import game_outcomes
from triple_agent.classes.roles import Roles
from triple_agent.classes.outcomes import WinType
from triple_agent.classes.missions import Missions, MissionStatus
from triple_agent.reports.generation.common_sort_functions import sort_by_spy_wins, sort_by_sniper_wins
from triple_agent.reports.generation.plot_specs import AxisProperties, DataQueryProperties, PlotLabelStyle
from triple_agent.reports.specific.action_tests import action_test_percentages, diff_action_test_percentages
from triple_agent.reports.specific.mission_choices import mission_choices
from triple_agent.reports.specific.mission_completes import mission_completion_query, mission_completion, _mission_completes_details
from triple_agent.classes.action_tests import ActionTest
from collections import Counter, defaultdict
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
replays = get_parsed_replays(lambda g: True)

# %%
game_outcomes(
    replays,
    DataQueryProperties(
        groupby=lambda g: g.event,
        secondary_order=['Summer Cup 2018', 'SCL4', 'Winter Cup 2019', 'SCL5', 'Summer Cup 2019'],
    ),
    axis_properties=AxisProperties(title="Game Outcomes by Event")
).frame
# Out:
#                       Summer Cup 2018  SCL4  Winter Cup 2019  SCL5  \
# WinType.TimeOut                    12   225               39   215
# WinType.SpyShot                   218  2093              323  2198
# WinType.MissionsWin               127   863              133  1022
# WinType.CivilianShot               93  1009              144  1079
#
#                       Summer Cup 2019
# WinType.TimeOut                    57
# WinType.SpyShot                   531
# WinType.MissionsWin               218
# WinType.CivilianShot              221

# %%
game_outcomes(
    replays,
    DataQueryProperties(
        groupby=lambda g: g.event,
        secondary_order=['Summer Cup 2018', 'SCL4', 'Winter Cup 2019', 'SCL5', 'Summer Cup 2019'],
        percent_normalized_data=True
    ),
    axis_properties=AxisProperties(
        title="Game Outcomes by Event",
        force_line=True,
    )
).frame
# Out:
#                       Summer Cup 2018      SCL4  Winter Cup 2019      SCL5  \
# WinType.TimeOut              0.026667  0.053699         0.061033  0.047630
# WinType.SpyShot              0.484444  0.499523         0.505477  0.486930
# WinType.MissionsWin          0.282222  0.205967         0.208138  0.226407
# WinType.CivilianShot         0.206667  0.240811         0.225352  0.239034
#
#                       Summer Cup 2019
# WinType.TimeOut              0.055501
# WinType.SpyShot              0.517040
# WinType.MissionsWin          0.212269
# WinType.CivilianShot         0.215190
