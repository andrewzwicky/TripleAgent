# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
project_path = str(Path().joinpath('..', 'triple_agent').resolve())
sys.path.append(project_path)
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.replays.get_parsed_replays import get_parsed_replays
from triple_agent.utilities.event_constants import select_scl5_with_drops
from triple_agent.reports.action_tests import _at_rates_excluding_difficults
from triple_agent.reports.plot_utilities import create_data_dictionaries
from pprint import pprint # pretty printing

# %%
scl5_replays = get_parsed_replays(select_scl5_with_drops)

# %% [markdown]
# ####  `create_data_dictionary(games, query_function, groupby)`
#
# `create_data_dictionary` will output a dictionary, populated by the `query_function`.  The `query_function` takes a list of games, analyzes some specific aspect of the games, and populate the data_dictionary with the data.  In this specific example, the `query_function` is `_at_rates_excluding_difficults`, which is a simple counter of each type of action test.  In this particular case, we are also taking advantage of the `groupby` functionality, to show that we want to group the games by spy.  This means that we will receive a separate counter of action tests *per spy*.  `groupby` is very powerful and allows for groupbing based on spy, sniper, venue, event, division, etc.

# %%
data_dict, data_counts = create_data_dictionary(scl5_replays, _at_rates_excluding_difficults, lambda game: game.spy)

# %% [markdown]
# This is an example of the python representation, including the enumerated names for the action tests.

# %%
len(data_dict.keys())
# Out:
# 106

# %%
pprint(data_dict)
# Out:
# defaultdict(<class 'collections.Counter'>,
#             {'Alexare': Counter({<ActionTest.White: 2>: 165,
#                                  <ActionTest.Green: 1>: 92,
#                                  <ActionTest.Red: 4>: 7,
#                                  <ActionTest.Canceled: 5>: 1}),
#              'AndiVx': Counter({<ActionTest.White: 2>: 123,
#                                 <ActionTest.Green: 1>: 64,
#                                 <ActionTest.Red: 4>: 5,
#                                 <ActionTest.Canceled: 5>: 2,
#                                 <ActionTest.Ignored: 3>: 1}),
#              'Calvin Schoolidge': Counter({<ActionTest.White: 2>: 163,
#                                            <ActionTest.Green: 1>: 88,
#                                            <ActionTest.Ignored: 3>: 14,
#                                            <ActionTest.Red: 4>: 13,
#                                            <ActionTest.Canceled: 5>: 4}),
#              'Cartwright': Counter({<ActionTest.Green: 1>: 146,
#                                     <ActionTest.White: 2>: 135,
#                                     <ActionTest.Canceled: 5>: 5,
#                                     <ActionTest.Red: 4>: 2}),
#              'Harren': Counter({<ActionTest.White: 2>: 167,
#                                 <ActionTest.Green: 1>: 60,
#                                 <ActionTest.Canceled: 5>: 2,
#                                 <ActionTest.Red: 4>: 2,
#                                 <ActionTest.Ignored: 3>: 1}),
#              'Hectic': Counter({<ActionTest.Green: 1>: 59,
#                                 <ActionTest.White: 2>: 42,
#                                 <ActionTest.Red: 4>: 2}),
#              'InfamousCupcake': Counter({<ActionTest.White: 2>: 142,
#                                          <ActionTest.Green: 1>: 61,
#                                          <ActionTest.Red: 4>: 4,
#                                          <ActionTest.Canceled: 5>: 2}),
#              'Kmars133': Counter({<ActionTest.White: 2>: 189,
#                                   <ActionTest.Green: 1>: 74,
#                                   <ActionTest.Red: 4>: 7,
#                                   <ActionTest.Canceled: 5>: 1}),
#              'Kotte': Counter({<ActionTest.White: 2>: 149,
#                                <ActionTest.Green: 1>: 90,
#                                <ActionTest.Red: 4>: 4,
#                                <ActionTest.Canceled: 5>: 3,
#                                <ActionTest.Ignored: 3>: 2}),
#              'Legorve Genine': Counter({<ActionTest.White: 2>: 122,
#                                         <ActionTest.Green: 1>: 67,
#                                         <ActionTest.Red: 4>: 10,
#                                         <ActionTest.Ignored: 3>: 7,
#                                         <ActionTest.Canceled: 5>: 3}),
#              'Libro': Counter({<ActionTest.White: 2>: 45,
#                                <ActionTest.Green: 1>: 36,
#                                <ActionTest.Ignored: 3>: 2,
#                                <ActionTest.Canceled: 5>: 1}),
#              'Max Edward Snax': Counter({<ActionTest.White: 2>: 152,
#                                          <ActionTest.Green: 1>: 100,
#                                          <ActionTest.Red: 4>: 7,
#                                          <ActionTest.Canceled: 5>: 3}),
#              'OpiWrites': Counter({<ActionTest.Green: 1>: 131,
#                                    <ActionTest.White: 2>: 123,
#                                    <ActionTest.Canceled: 5>: 4,
#                                    <ActionTest.Red: 4>: 4,
#                                    <ActionTest.Ignored: 3>: 1}),
#              'PixelBandit': Counter({<ActionTest.White: 2>: 4,
#                                      <ActionTest.Ignored: 3>: 1}),
#              'Pizzelio': Counter({<ActionTest.White: 2>: 93,
#                                   <ActionTest.Green: 1>: 64,
#                                   <ActionTest.Ignored: 3>: 2,
#                                   <ActionTest.Red: 4>: 2,
#                                   <ActionTest.Canceled: 5>: 1}),
#              'Rai': Counter({<ActionTest.White: 2>: 55,
#                              <ActionTest.Green: 1>: 23,
#                              <ActionTest.Canceled: 5>: 2}),
#              'Ranmilia': Counter({<ActionTest.White: 2>: 162,
#                                   <ActionTest.Green: 1>: 105,
#                                   <ActionTest.Red: 4>: 3,
#                                   <ActionTest.Ignored: 3>: 2,
#                                   <ActionTest.Canceled: 5>: 1}),
#              'Rooks': Counter({<ActionTest.White: 2>: 127,
#                                <ActionTest.Green: 1>: 122,
#                                <ActionTest.Red: 4>: 5,
#                                <ActionTest.Canceled: 5>: 2}),
#              'Ryooo': Counter({<ActionTest.White: 2>: 141,
#                                <ActionTest.Green: 1>: 125,
#                                <ActionTest.Ignored: 3>: 10,
#                                <ActionTest.Canceled: 5>: 3,
#                                <ActionTest.Red: 4>: 2}),
#              'Sheph': Counter({<ActionTest.White: 2>: 127,
#                                <ActionTest.Green: 1>: 104,
#                                <ActionTest.Red: 4>: 14,
#                                <ActionTest.Ignored: 3>: 9,
#                                <ActionTest.Canceled: 5>: 4}),
#              'Silverthorn': Counter({<ActionTest.White: 2>: 100,
#                                      <ActionTest.Green: 1>: 63,
#                                      <ActionTest.Red: 4>: 5,
#                                      <ActionTest.Canceled: 5>: 4,
#                                      <ActionTest.Ignored: 3>: 1}),
#              'Smiddy': Counter({<ActionTest.White: 2>: 89,
#                                 <ActionTest.Green: 1>: 49,
#                                 <ActionTest.Red: 4>: 2}),
#              'Sun Bro': Counter({<ActionTest.White: 2>: 169,
#                                  <ActionTest.Green: 1>: 127,
#                                  <ActionTest.Red: 4>: 4,
#                                  <ActionTest.Ignored: 3>: 2,
#                                  <ActionTest.Canceled: 5>: 1}),
#              'Tabsies': Counter({<ActionTest.White: 2>: 145,
#                                  <ActionTest.Green: 1>: 98,
#                                  <ActionTest.Ignored: 3>: 33,
#                                  <ActionTest.Red: 4>: 9,
#                                  <ActionTest.Canceled: 5>: 6}),
#              'ThatOdinaryPlayer': Counter({<ActionTest.Green: 1>: 22,
#                                            <ActionTest.White: 2>: 15,
#                                            <ActionTest.Red: 4>: 2}),
#              'TheSmiddy': Counter({<ActionTest.White: 2>: 69,
#                                    <ActionTest.Green: 1>: 41,
#                                    <ActionTest.Red: 4>: 2,
#                                    <ActionTest.Canceled: 5>: 1}),
#              'Tortuga-Man': Counter({<ActionTest.White: 2>: 48,
#                                      <ActionTest.Green: 1>: 18,
#                                      <ActionTest.Red: 4>: 3,
#                                      <ActionTest.Canceled: 5>: 1,
#                                      <ActionTest.Ignored: 3>: 1}),
#              'Vac58': Counter({<ActionTest.White: 2>: 141,
#                                <ActionTest.Green: 1>: 96,
#                                <ActionTest.Red: 4>: 7,
#                                <ActionTest.Canceled: 5>: 2,
#                                <ActionTest.Ignored: 3>: 1}),
#              'Vlady': Counter({<ActionTest.Green: 1>: 4,
#                                <ActionTest.White: 2>: 3}),
#              'Watermeat': Counter({<ActionTest.White: 2>: 172,
#                                    <ActionTest.Green: 1>: 95,
#                                    <ActionTest.Ignored: 3>: 9,
#                                    <ActionTest.Red: 4>: 3,
#                                    <ActionTest.Canceled: 5>: 2}),
#              'Yglini': Counter({<ActionTest.White: 2>: 145,
#                                 <ActionTest.Green: 1>: 74,
#                                 <ActionTest.Red: 4>: 7,
#                                 <ActionTest.Canceled: 5>: 2}),
#              'alibi': Counter({<ActionTest.White: 2>: 164,
#                                <ActionTest.Green: 1>: 70,
#                                <ActionTest.Canceled: 5>: 5,
#                                <ActionTest.Red: 4>: 3}),
#              'alteffor': Counter({<ActionTest.White: 2>: 113,
#                                   <ActionTest.Green: 1>: 44,
#                                   <ActionTest.Red: 4>: 4,
#                                   <ActionTest.Canceled: 5>: 2,
#                                   <ActionTest.Ignored: 3>: 1}),
#              'amlabella': Counter({<ActionTest.White: 2>: 156,
#                                    <ActionTest.Green: 1>: 127,
#                                    <ActionTest.Red: 4>: 4,
#                                    <ActionTest.Canceled: 5>: 2}),
#              'arturiax': Counter({<ActionTest.White: 2>: 160,
#                                   <ActionTest.Green: 1>: 94,
#                                   <ActionTest.Red: 4>: 5,
#                                   <ActionTest.Canceled: 5>: 4,
#                                   <ActionTest.Ignored: 3>: 1}),
#              'ascendbeyond': Counter({<ActionTest.White: 2>: 100,
#                                       <ActionTest.Green: 1>: 67,
#                                       <ActionTest.Red: 4>: 5,
#                                       <ActionTest.Canceled: 5>: 3}),
#              'bananaconda': Counter({<ActionTest.White: 2>: 172,
#                                      <ActionTest.Green: 1>: 85,
#                                      <ActionTest.Ignored: 3>: 9,
#                                      <ActionTest.Red: 4>: 6,
#                                      <ActionTest.Canceled: 5>: 6}),
#              'belial': Counter({<ActionTest.White: 2>: 72,
#                                 <ActionTest.Green: 1>: 24,
#                                 <ActionTest.Red: 4>: 1}),
#              'brskaylor': Counter({<ActionTest.White: 2>: 37,
#                                    <ActionTest.Green: 1>: 28,
#                                    <ActionTest.Canceled: 5>: 2,
#                                    <ActionTest.Red: 4>: 1}),
#              'canadianbacon': Counter({<ActionTest.Green: 1>: 133,
#                                        <ActionTest.White: 2>: 133,
#                                        <ActionTest.Red: 4>: 4,
#                                        <ActionTest.Canceled: 5>: 2,
#                                        <ActionTest.Ignored: 3>: 1}),
#              'checker': Counter({<ActionTest.White: 2>: 147,
#                                  <ActionTest.Green: 1>: 66,
#                                  <ActionTest.Red: 4>: 4,
#                                  <ActionTest.Canceled: 5>: 1}),
#              'cleetose': Counter({<ActionTest.White: 2>: 161,
#                                   <ActionTest.Green: 1>: 73,
#                                   <ActionTest.Red: 4>: 8,
#                                   <ActionTest.Ignored: 3>: 1}),
#              'daheadhunter': Counter({<ActionTest.White: 2>: 130,
#                                       <ActionTest.Green: 1>: 64,
#                                       <ActionTest.Red: 4>: 7,
#                                       <ActionTest.Canceled: 5>: 2}),
#              'davidw': Counter({<ActionTest.White: 2>: 148,
#                                 <ActionTest.Green: 1>: 116,
#                                 <ActionTest.Red: 4>: 7,
#                                 <ActionTest.Canceled: 5>: 1,
#                                 <ActionTest.Ignored: 3>: 1}),
#              'dbdkmezz': Counter({<ActionTest.White: 2>: 210,
#                                   <ActionTest.Green: 1>: 63,
#                                   <ActionTest.Ignored: 3>: 9,
#                                   <ActionTest.Red: 4>: 8,
#                                   <ActionTest.Canceled: 5>: 4}),
#              'degran': Counter({<ActionTest.White: 2>: 181,
#                                 <ActionTest.Green: 1>: 105,
#                                 <ActionTest.Red: 4>: 4,
#                                 <ActionTest.Canceled: 5>: 3,
#                                 <ActionTest.Ignored: 3>: 2}),
#              'dels': Counter({<ActionTest.White: 2>: 109,
#                               <ActionTest.Green: 1>: 109,
#                               <ActionTest.Red: 4>: 3,
#                               <ActionTest.Ignored: 3>: 2}),
#              'dowsey': Counter({<ActionTest.White: 2>: 133,
#                                 <ActionTest.Green: 1>: 117,
#                                 <ActionTest.Red: 4>: 5,
#                                 <ActionTest.Canceled: 5>: 2}),
#              'dukit': Counter({<ActionTest.White: 2>: 160,
#                                <ActionTest.Green: 1>: 75,
#                                <ActionTest.Red: 4>: 5,
#                                <ActionTest.Ignored: 3>: 4,
#                                <ActionTest.Canceled: 5>: 2}),
#              'ekajarmstro': Counter({<ActionTest.White: 2>: 179,
#                                      <ActionTest.Green: 1>: 153,
#                                      <ActionTest.Ignored: 3>: 4,
#                                      <ActionTest.Red: 4>: 4,
#                                      <ActionTest.Canceled: 5>: 3}),
#              'falconhit': Counter({<ActionTest.White: 2>: 160,
#                                    <ActionTest.Green: 1>: 136,
#                                    <ActionTest.Red: 4>: 5,
#                                    <ActionTest.Canceled: 5>: 2}),
#              'fancypants': Counter({<ActionTest.White: 2>: 206,
#                                     <ActionTest.Green: 1>: 87,
#                                     <ActionTest.Ignored: 3>: 5,
#                                     <ActionTest.Red: 4>: 4,
#                                     <ActionTest.Canceled: 5>: 2}),
#              'furbyfubar': Counter({<ActionTest.White: 2>: 174,
#                                     <ActionTest.Green: 1>: 106,
#                                     <ActionTest.Red: 4>: 12,
#                                     <ActionTest.Canceled: 5>: 3,
#                                     <ActionTest.Ignored: 3>: 2}),
#              'gabrio': Counter({<ActionTest.White: 2>: 146,
#                                 <ActionTest.Green: 1>: 110,
#                                 <ActionTest.Red: 4>: 5,
#                                 <ActionTest.Canceled: 5>: 2}),
#              'gmantsang': Counter({<ActionTest.White: 2>: 148,
#                                    <ActionTest.Green: 1>: 76,
#                                    <ActionTest.Ignored: 3>: 11,
#                                    <ActionTest.Red: 4>: 3,
#                                    <ActionTest.Canceled: 5>: 3}),
#              'howiie': Counter({<ActionTest.White: 2>: 142,
#                                 <ActionTest.Green: 1>: 52,
#                                 <ActionTest.Red: 4>: 11,
#                                 <ActionTest.Ignored: 3>: 5,
#                                 <ActionTest.Canceled: 5>: 1}),
#              'humankirby': Counter({<ActionTest.White: 2>: 133,
#                                     <ActionTest.Green: 1>: 83,
#                                     <ActionTest.Red: 4>: 5,
#                                     <ActionTest.Canceled: 5>: 2}),
#              'hunu': Counter({<ActionTest.White: 2>: 216,
#                               <ActionTest.Green: 1>: 89,
#                               <ActionTest.Ignored: 3>: 21,
#                               <ActionTest.Red: 4>: 3,
#                               <ActionTest.Canceled: 5>: 1}),
#              'iggythegrifter': Counter({<ActionTest.White: 2>: 122,
#                                         <ActionTest.Green: 1>: 69,
#                                         <ActionTest.Red: 4>: 4,
#                                         <ActionTest.Ignored: 3>: 3}),
#              'jd105l': Counter({<ActionTest.White: 2>: 100,
#                                 <ActionTest.Green: 1>: 76,
#                                 <ActionTest.Ignored: 3>: 4,
#                                 <ActionTest.Red: 4>: 2}),
#              'juliusb': Counter({<ActionTest.White: 2>: 33,
#                                  <ActionTest.Green: 1>: 15,
#                                  <ActionTest.Red: 4>: 3,
#                                  <ActionTest.Ignored: 3>: 2}),
#              'jyaty': Counter({<ActionTest.White: 2>: 133,
#                                <ActionTest.Green: 1>: 85,
#                                <ActionTest.Canceled: 5>: 2,
#                                <ActionTest.Red: 4>: 2}),
#              'kcmmmmm': Counter({<ActionTest.Green: 1>: 117,
#                                  <ActionTest.White: 2>: 103,
#                                  <ActionTest.Red: 4>: 10,
#                                  <ActionTest.Ignored: 3>: 2,
#                                  <ActionTest.Canceled: 5>: 2}),
#              'krazycaley': Counter({<ActionTest.White: 2>: 124,
#                                     <ActionTest.Green: 1>: 120,
#                                     <ActionTest.Red: 4>: 6,
#                                     <ActionTest.Canceled: 5>: 2}),
#              'lazybear': Counter({<ActionTest.Green: 1>: 127,
#                                   <ActionTest.White: 2>: 103,
#                                   <ActionTest.Canceled: 5>: 5,
#                                   <ActionTest.Red: 4>: 3}),
#              'linkvanyali': Counter({<ActionTest.White: 2>: 21,
#                                      <ActionTest.Green: 1>: 11,
#                                      <ActionTest.Ignored: 3>: 1}),
#              'magicdoer1': Counter({<ActionTest.White: 2>: 128,
#                                     <ActionTest.Green: 1>: 121,
#                                     <ActionTest.Ignored: 3>: 16,
#                                     <ActionTest.Red: 4>: 10,
#                                     <ActionTest.Canceled: 5>: 4}),
#              'magician1099': Counter({<ActionTest.White: 2>: 157,
#                                       <ActionTest.Green: 1>: 89,
#                                       <ActionTest.Red: 4>: 8,
#                                       <ActionTest.Canceled: 5>: 3,
#                                       <ActionTest.Ignored: 3>: 1}),
#              'mintyrug': Counter({<ActionTest.White: 2>: 84,
#                                   <ActionTest.Green: 1>: 63,
#                                   <ActionTest.Red: 4>: 4,
#                                   <ActionTest.Ignored: 3>: 1}),
#              'ml726': Counter({<ActionTest.White: 2>: 67,
#                                <ActionTest.Green: 1>: 53,
#                                <ActionTest.Canceled: 5>: 5,
#                                <ActionTest.Red: 4>: 3,
#                                <ActionTest.Ignored: 3>: 2}),
#              'monaters': Counter({<ActionTest.White: 2>: 144,
#                                   <ActionTest.Green: 1>: 63,
#                                   <ActionTest.Red: 4>: 10,
#                                   <ActionTest.Canceled: 5>: 2}),
#              'mrrgrs': Counter({<ActionTest.White: 2>: 161,
#                                 <ActionTest.Green: 1>: 98,
#                                 <ActionTest.Red: 4>: 8,
#                                 <ActionTest.Ignored: 3>: 2,
#                                 <ActionTest.Canceled: 5>: 2}),
#              'mrtwister': Counter({<ActionTest.White: 2>: 202,
#                                    <ActionTest.Green: 1>: 88,
#                                    <ActionTest.Red: 4>: 20,
#                                    <ActionTest.Canceled: 5>: 4,
#                                    <ActionTest.Ignored: 3>: 1}),
#              'ninjafairy': Counter({<ActionTest.White: 2>: 163,
#                                     <ActionTest.Green: 1>: 69,
#                                     <ActionTest.Red: 4>: 4,
#                                     <ActionTest.Canceled: 5>: 4}),
#              'orac': Counter({<ActionTest.White: 2>: 170,
#                               <ActionTest.Green: 1>: 73,
#                               <ActionTest.Canceled: 5>: 5,
#                               <ActionTest.Red: 4>: 4,
#                               <ActionTest.Ignored: 3>: 3}),
#              'paratroopa': Counter({<ActionTest.White: 2>: 174,
#                                     <ActionTest.Green: 1>: 72,
#                                     <ActionTest.Canceled: 5>: 5,
#                                     <ActionTest.Red: 4>: 4}),
#              'phimagen': Counter({<ActionTest.White: 2>: 120,
#                                   <ActionTest.Green: 1>: 23,
#                                   <ActionTest.Red: 4>: 7}),
#              'pofke': Counter({<ActionTest.White: 2>: 124,
#                                <ActionTest.Green: 1>: 86,
#                                <ActionTest.Ignored: 3>: 12,
#                                <ActionTest.Red: 4>: 4,
#                                <ActionTest.Canceled: 5>: 2}),
#              'portalfreek': Counter({<ActionTest.White: 2>: 121,
#                                      <ActionTest.Green: 1>: 92,
#                                      <ActionTest.Ignored: 3>: 4,
#                                      <ActionTest.Red: 4>: 3,
#                                      <ActionTest.Canceled: 5>: 2}),
#              'pox': Counter({<ActionTest.White: 2>: 133,
#                              <ActionTest.Green: 1>: 111,
#                              <ActionTest.Ignored: 3>: 9,
#                              <ActionTest.Red: 4>: 1,
#                              <ActionTest.Canceled: 5>: 1}),
#              'pwndnoob': Counter({<ActionTest.White: 2>: 144,
#                                   <ActionTest.Green: 1>: 119,
#                                   <ActionTest.Canceled: 5>: 5,
#                                   <ActionTest.Red: 4>: 3,
#                                   <ActionTest.Ignored: 3>: 1}),
#              'quicklime': Counter({<ActionTest.White: 2>: 149,
#                                    <ActionTest.Green: 1>: 100,
#                                    <ActionTest.Ignored: 3>: 10,
#                                    <ActionTest.Canceled: 5>: 6,
#                                    <ActionTest.Red: 4>: 2}),
#              'rooks': Counter({<ActionTest.White: 2>: 22,
#                                <ActionTest.Green: 1>: 11,
#                                <ActionTest.Red: 4>: 1}),
#              'royalflush': Counter({<ActionTest.White: 2>: 137,
#                                     <ActionTest.Green: 1>: 90,
#                                     <ActionTest.Red: 4>: 5,
#                                     <ActionTest.Canceled: 5>: 3,
#                                     <ActionTest.Ignored: 3>: 1}),
#              'rta': Counter({<ActionTest.White: 2>: 12,
#                              <ActionTest.Green: 1>: 2}),
#              'scallions': Counter({<ActionTest.White: 2>: 141,
#                                    <ActionTest.Green: 1>: 125,
#                                    <ActionTest.Canceled: 5>: 3,
#                                    <ActionTest.Red: 4>: 2,
#                                    <ActionTest.Ignored: 3>: 1}),
#              'sergioc89': Counter({<ActionTest.White: 2>: 56,
#                                    <ActionTest.Green: 1>: 39,
#                                    <ActionTest.Red: 4>: 2,
#                                    <ActionTest.Canceled: 5>: 1,
#                                    <ActionTest.Ignored: 3>: 1}),
#              'sgnurf': Counter({<ActionTest.White: 2>: 145,
#                                 <ActionTest.Green: 1>: 73,
#                                 <ActionTest.Canceled: 5>: 3,
#                                 <ActionTest.Red: 4>: 3,
#                                 <ActionTest.Ignored: 3>: 2}),
#              'skrewwl00se': Counter({<ActionTest.Green: 1>: 154,
#                                      <ActionTest.White: 2>: 136,
#                                      <ActionTest.Red: 4>: 5,
#                                      <ActionTest.Ignored: 3>: 1}),
#              'slappydavis': Counter({<ActionTest.White: 2>: 141,
#                                      <ActionTest.Green: 1>: 139,
#                                      <ActionTest.Red: 4>: 15,
#                                      <ActionTest.Canceled: 5>: 3,
#                                      <ActionTest.Ignored: 3>: 1}),
#              'smonteGaming': Counter({<ActionTest.White: 2>: 174,
#                                       <ActionTest.Green: 1>: 99,
#                                       <ActionTest.Red: 4>: 11,
#                                       <ActionTest.Canceled: 5>: 6,
#                                       <ActionTest.Ignored: 3>: 1}),
#              'soolseem': Counter({<ActionTest.White: 2>: 138,
#                                   <ActionTest.Green: 1>: 79,
#                                   <ActionTest.Ignored: 3>: 13,
#                                   <ActionTest.Red: 4>: 6,
#                                   <ActionTest.Canceled: 5>: 2}),
#              'spedmonkey': Counter({<ActionTest.White: 2>: 147,
#                                     <ActionTest.Green: 1>: 134,
#                                     <ActionTest.Ignored: 3>: 8,
#                                     <ActionTest.Red: 4>: 2}),
#              'sykosloth': Counter({<ActionTest.White: 2>: 148,
#                                    <ActionTest.Green: 1>: 130,
#                                    <ActionTest.Red: 4>: 5,
#                                    <ActionTest.Canceled: 5>: 3,
#                                    <ActionTest.Ignored: 3>: 2}),
#              'tflameee': Counter({<ActionTest.White: 2>: 115,
#                                   <ActionTest.Green: 1>: 90,
#                                   <ActionTest.Ignored: 3>: 8,
#                                   <ActionTest.Red: 4>: 2,
#                                   <ActionTest.Canceled: 5>: 2}),
#              'tge': Counter({<ActionTest.Green: 1>: 14,
#                              <ActionTest.White: 2>: 9,
#                              <ActionTest.Red: 4>: 1}),
#              'the_usual_toaster': Counter({<ActionTest.White: 2>: 131,
#                                            <ActionTest.Green: 1>: 66,
#                                            <ActionTest.Ignored: 3>: 20,
#                                            <ActionTest.Red: 4>: 12,
#                                            <ActionTest.Canceled: 5>: 4}),
#              'turnipboy': Counter({<ActionTest.White: 2>: 156,
#                                    <ActionTest.Green: 1>: 121,
#                                    <ActionTest.Red: 4>: 5,
#                                    <ActionTest.Canceled: 5>: 2,
#                                    <ActionTest.Ignored: 3>: 1}),
#              'turnout8': Counter({<ActionTest.White: 2>: 138,
#                                   <ActionTest.Green: 1>: 83,
#                                   <ActionTest.Red: 4>: 3}),
#              'umbertofinito': Counter({<ActionTest.White: 2>: 76,
#                                        <ActionTest.Green: 1>: 12,
#                                        <ActionTest.Canceled: 5>: 1,
#                                        <ActionTest.Ignored: 3>: 1}),
#              'ventuskitsune': Counter({<ActionTest.White: 2>: 149,
#                                        <ActionTest.Green: 1>: 88,
#                                        <ActionTest.Red: 4>: 3,
#                                        <ActionTest.Canceled: 5>: 3}),
#              'warningtrack': Counter({<ActionTest.Green: 1>: 162,
#                                       <ActionTest.White: 2>: 117,
#                                       <ActionTest.Ignored: 3>: 19,
#                                       <ActionTest.Red: 4>: 2,
#                                       <ActionTest.Canceled: 5>: 1}),
#              'wodar': Counter({<ActionTest.White: 2>: 137,
#                                <ActionTest.Green: 1>: 114,
#                                <ActionTest.Red: 4>: 7,
#                                <ActionTest.Ignored: 3>: 2,
#                                <ActionTest.Canceled: 5>: 2}),
#              'yeesh': Counter({<ActionTest.White: 2>: 107,
#                                <ActionTest.Green: 1>: 106,
#                                <ActionTest.Red: 4>: 4,
#                                <ActionTest.Canceled: 5>: 3}),
#              'yerand': Counter({<ActionTest.White: 2>: 163,
#                                 <ActionTest.Green: 1>: 82,
#                                 <ActionTest.Canceled: 5>: 5,
#                                 <ActionTest.Red: 4>: 5}),
#              'zerodoom': Counter({<ActionTest.White: 2>: 159,
#                                   <ActionTest.Green: 1>: 67,
#                                   <ActionTest.Red: 4>: 4,
#                                   <ActionTest.Canceled: 5>: 3})})

# %% [markdown]
# Because this output is a `Counter` class, which is a type of python `dictionary`, we can output JSON without any additional code.

# %%
import json

# %%
print(json.dumps(data_dict, indent=4))
# Out:
# {
#     "Alexare": {
#         "2": 165,
#         "1": 92,
#         "5": 1,
#         "4": 7
#     },
#     "AndiVx": {
#         "2": 123,
#         "1": 64,
#         "4": 5,
#         "5": 2,
#         "3": 1
#     },
#     "Calvin Schoolidge": {
#         "2": 163,
#         "1": 88,
#         "3": 14,
#         "4": 13,
#         "5": 4
#     },
#     "Cartwright": {
#         "2": 135,
#         "1": 146,
#         "4": 2,
#         "5": 5
#     },
#     "Harren": {
#         "2": 167,
#         "1": 60,
#         "3": 1,
#         "5": 2,
#         "4": 2
#     },
#     "Hectic": {
#         "2": 42,
#         "1": 59,
#         "4": 2
#     },
#     "InfamousCupcake": {
#         "1": 61,
#         "2": 142,
#         "5": 2,
#         "4": 4
#     },
#     "Kmars133": {
#         "2": 189,
#         "1": 74,
#         "4": 7,
#         "5": 1
#     },
#     "Kotte": {
#         "2": 149,
#         "1": 90,
#         "4": 4,
#         "3": 2,
#         "5": 3
#     },
#     "Legorve Genine": {
#         "2": 122,
#         "1": 67,
#         "4": 10,
#         "3": 7,
#         "5": 3
#     },
#     "Libro": {
#         "1": 36,
#         "2": 45,
#         "3": 2,
#         "5": 1
#     },
#     "Max Edward Snax": {
#         "2": 152,
#         "1": 100,
#         "4": 7,
#         "5": 3
#     },
#     "OpiWrites": {
#         "1": 131,
#         "2": 123,
#         "5": 4,
#         "4": 4,
#         "3": 1
#     },
#     "PixelBandit": {
#         "3": 1,
#         "2": 4
#     },
#     "Pizzelio": {
#         "1": 64,
#         "2": 93,
#         "3": 2,
#         "5": 1,
#         "4": 2
#     },
#     "Rai": {
#         "2": 55,
#         "1": 23,
#         "5": 2
#     },
#     "Ranmilia": {
#         "2": 162,
#         "1": 105,
#         "4": 3,
#         "3": 2,
#         "5": 1
#     },
#     "Rooks": {
#         "2": 127,
#         "1": 122,
#         "4": 5,
#         "5": 2
#     },
#     "Ryooo": {
#         "2": 141,
#         "4": 2,
#         "1": 125,
#         "3": 10,
#         "5": 3
#     },
#     "Sheph": {
#         "2": 127,
#         "5": 4,
#         "1": 104,
#         "3": 9,
#         "4": 14
#     },
#     "Silverthorn": {
#         "1": 63,
#         "2": 100,
#         "5": 4,
#         "4": 5,
#         "3": 1
#     },
#     "Smiddy": {
#         "2": 89,
#         "1": 49,
#         "4": 2
#     },
#     "Sun Bro": {
#         "2": 169,
#         "1": 127,
#         "4": 4,
#         "5": 1,
#         "3": 2
#     },
#     "Tabsies": {
#         "1": 98,
#         "2": 145,
#         "5": 6,
#         "3": 33,
#         "4": 9
#     },
#     "ThatOdinaryPlayer": {
#         "2": 15,
#         "1": 22,
#         "4": 2
#     },
#     "TheSmiddy": {
#         "2": 69,
#         "4": 2,
#         "1": 41,
#         "5": 1
#     },
#     "Tortuga-Man": {
#         "1": 18,
#         "4": 3,
#         "2": 48,
#         "5": 1,
#         "3": 1
#     },
#     "Vac58": {
#         "2": 141,
#         "1": 96,
#         "4": 7,
#         "5": 2,
#         "3": 1
#     },
#     "Vlady": {
#         "2": 3,
#         "1": 4
#     },
#     "Watermeat": {
#         "2": 172,
#         "1": 95,
#         "3": 9,
#         "4": 3,
#         "5": 2
#     },
#     "Yglini": {
#         "2": 145,
#         "1": 74,
#         "4": 7,
#         "5": 2
#     },
#     "alibi": {
#         "1": 70,
#         "2": 164,
#         "5": 5,
#         "4": 3
#     },
#     "alteffor": {
#         "1": 44,
#         "2": 113,
#         "4": 4,
#         "5": 2,
#         "3": 1
#     },
#     "amlabella": {
#         "2": 156,
#         "1": 127,
#         "5": 2,
#         "4": 4
#     },
#     "arturiax": {
#         "1": 94,
#         "2": 160,
#         "4": 5,
#         "5": 4,
#         "3": 1
#     },
#     "ascendbeyond": {
#         "1": 67,
#         "2": 100,
#         "5": 3,
#         "4": 5
#     },
#     "bananaconda": {
#         "2": 172,
#         "1": 85,
#         "3": 9,
#         "4": 6,
#         "5": 6
#     },
#     "belial": {
#         "2": 72,
#         "1": 24,
#         "4": 1
#     },
#     "brskaylor": {
#         "2": 37,
#         "1": 28,
#         "5": 2,
#         "4": 1
#     },
#     "canadianbacon": {
#         "1": 133,
#         "2": 133,
#         "5": 2,
#         "4": 4,
#         "3": 1
#     },
#     "checker": {
#         "2": 147,
#         "1": 66,
#         "4": 4,
#         "5": 1
#     },
#     "cleetose": {
#         "2": 161,
#         "1": 73,
#         "4": 8,
#         "3": 1
#     },
#     "daheadhunter": {
#         "1": 64,
#         "2": 130,
#         "4": 7,
#         "5": 2
#     },
#     "davidw": {
#         "1": 116,
#         "2": 148,
#         "4": 7,
#         "5": 1,
#         "3": 1
#     },
#     "dbdkmezz": {
#         "2": 210,
#         "5": 4,
#         "1": 63,
#         "3": 9,
#         "4": 8
#     },
#     "degran": {
#         "2": 181,
#         "1": 105,
#         "4": 4,
#         "3": 2,
#         "5": 3
#     },
#     "dels": {
#         "2": 109,
#         "1": 109,
#         "4": 3,
#         "3": 2
#     },
#     "dowsey": {
#         "1": 117,
#         "2": 133,
#         "4": 5,
#         "5": 2
#     },
#     "dukit": {
#         "1": 75,
#         "2": 160,
#         "5": 2,
#         "3": 4,
#         "4": 5
#     },
#     "ekajarmstro": {
#         "2": 179,
#         "1": 153,
#         "3": 4,
#         "4": 4,
#         "5": 3
#     },
#     "falconhit": {
#         "1": 136,
#         "2": 160,
#         "4": 5,
#         "5": 2
#     },
#     "fancypants": {
#         "1": 87,
#         "2": 206,
#         "3": 5,
#         "4": 4,
#         "5": 2
#     },
#     "furbyfubar": {
#         "2": 174,
#         "1": 106,
#         "4": 12,
#         "3": 2,
#         "5": 3
#     },
#     "gabrio": {
#         "2": 146,
#         "1": 110,
#         "4": 5,
#         "5": 2
#     },
#     "gmantsang": {
#         "1": 76,
#         "2": 148,
#         "3": 11,
#         "4": 3,
#         "5": 3
#     },
#     "howiie": {
#         "2": 142,
#         "1": 52,
#         "4": 11,
#         "5": 1,
#         "3": 5
#     },
#     "humankirby": {
#         "2": 133,
#         "1": 83,
#         "4": 5,
#         "5": 2
#     },
#     "hunu": {
#         "1": 89,
#         "2": 216,
#         "3": 21,
#         "4": 3,
#         "5": 1
#     },
#     "iggythegrifter": {
#         "1": 69,
#         "2": 122,
#         "3": 3,
#         "4": 4
#     },
#     "jd105l": {
#         "2": 100,
#         "1": 76,
#         "4": 2,
#         "3": 4
#     },
#     "juliusb": {
#         "2": 33,
#         "4": 3,
#         "1": 15,
#         "3": 2
#     },
#     "jyaty": {
#         "2": 133,
#         "1": 85,
#         "5": 2,
#         "4": 2
#     },
#     "kcmmmmm": {
#         "2": 103,
#         "1": 117,
#         "4": 10,
#         "3": 2,
#         "5": 2
#     },
#     "krazycaley": {
#         "2": 124,
#         "1": 120,
#         "4": 6,
#         "5": 2
#     },
#     "lazybear": {
#         "1": 127,
#         "2": 103,
#         "5": 5,
#         "4": 3
#     },
#     "linkvanyali": {
#         "2": 21,
#         "3": 1,
#         "1": 11
#     },
#     "magicdoer1": {
#         "1": 121,
#         "2": 128,
#         "3": 16,
#         "4": 10,
#         "5": 4
#     },
#     "magician1099": {
#         "1": 89,
#         "2": 157,
#         "5": 3,
#         "4": 8,
#         "3": 1
#     },
#     "mintyrug": {
#         "1": 63,
#         "2": 84,
#         "4": 4,
#         "3": 1
#     },
#     "ml726": {
#         "1": 53,
#         "2": 67,
#         "3": 2,
#         "4": 3,
#         "5": 5
#     },
#     "monaters": {
#         "1": 63,
#         "2": 144,
#         "4": 10,
#         "5": 2
#     },
#     "mrrgrs": {
#         "2": 161,
#         "1": 98,
#         "4": 8,
#         "3": 2,
#         "5": 2
#     },
#     "mrtwister": {
#         "1": 88,
#         "2": 202,
#         "4": 20,
#         "5": 4,
#         "3": 1
#     },
#     "ninjafairy": {
#         "1": 69,
#         "2": 163,
#         "4": 4,
#         "5": 4
#     },
#     "orac": {
#         "5": 5,
#         "1": 73,
#         "2": 170,
#         "3": 3,
#         "4": 4
#     },
#     "paratroopa": {
#         "1": 72,
#         "2": 174,
#         "4": 4,
#         "5": 5
#     },
#     "phimagen": {
#         "1": 23,
#         "2": 120,
#         "4": 7
#     },
#     "pofke": {
#         "2": 124,
#         "3": 12,
#         "1": 86,
#         "4": 4,
#         "5": 2
#     },
#     "portalfreek": {
#         "2": 121,
#         "1": 92,
#         "3": 4,
#         "5": 2,
#         "4": 3
#     },
#     "pox": {
#         "2": 133,
#         "1": 111,
#         "3": 9,
#         "4": 1,
#         "5": 1
#     },
#     "pwndnoob": {
#         "2": 144,
#         "1": 119,
#         "4": 3,
#         "5": 5,
#         "3": 1
#     },
#     "quicklime": {
#         "1": 100,
#         "2": 149,
#         "5": 6,
#         "3": 10,
#         "4": 2
#     },
#     "rooks": {
#         "1": 11,
#         "2": 22,
#         "4": 1
#     },
#     "royalflush": {
#         "1": 90,
#         "2": 137,
#         "5": 3,
#         "4": 5,
#         "3": 1
#     },
#     "rta": {
#         "2": 12,
#         "1": 2
#     },
#     "scallions": {
#         "2": 141,
#         "1": 125,
#         "5": 3,
#         "3": 1,
#         "4": 2
#     },
#     "sergioc89": {
#         "2": 56,
#         "1": 39,
#         "5": 1,
#         "4": 2,
#         "3": 1
#     },
#     "sgnurf": {
#         "2": 145,
#         "1": 73,
#         "5": 3,
#         "4": 3,
#         "3": 2
#     },
#     "skrewwl00se": {
#         "2": 136,
#         "1": 154,
#         "4": 5,
#         "3": 1
#     },
#     "slappydavis": {
#         "2": 141,
#         "1": 139,
#         "4": 15,
#         "3": 1,
#         "5": 3
#     },
#     "smonteGaming": {
#         "1": 99,
#         "2": 174,
#         "5": 6,
#         "4": 11,
#         "3": 1
#     },
#     "soolseem": {
#         "2": 138,
#         "1": 79,
#         "3": 13,
#         "4": 6,
#         "5": 2
#     },
#     "spedmonkey": {
#         "2": 147,
#         "1": 134,
#         "4": 2,
#         "3": 8
#     },
#     "sykosloth": {
#         "1": 130,
#         "2": 148,
#         "5": 3,
#         "4": 5,
#         "3": 2
#     },
#     "tflameee": {
#         "1": 90,
#         "2": 115,
#         "3": 8,
#         "4": 2,
#         "5": 2
#     },
#     "tge": {
#         "1": 14,
#         "2": 9,
#         "4": 1
#     },
#     "the_usual_toaster": {
#         "1": 66,
#         "3": 20,
#         "2": 131,
#         "4": 12,
#         "5": 4
#     },
#     "turnipboy": {
#         "1": 121,
#         "2": 156,
#         "4": 5,
#         "3": 1,
#         "5": 2
#     },
#     "turnout8": {
#         "2": 138,
#         "1": 83,
#         "4": 3
#     },
#     "umbertofinito": {
#         "2": 76,
#         "1": 12,
#         "5": 1,
#         "3": 1
#     },
#     "ventuskitsune": {
#         "1": 88,
#         "2": 149,
#         "4": 3,
#         "5": 3
#     },
#     "warningtrack": {
#         "1": 162,
#         "2": 117,
#         "3": 19,
#         "4": 2,
#         "5": 1
#     },
#     "wodar": {
#         "1": 114,
#         "2": 137,
#         "3": 2,
#         "4": 7,
#         "5": 2
#     },
#     "yeesh": {
#         "2": 107,
#         "1": 106,
#         "4": 4,
#         "5": 3
#     },
#     "yerand": {
#         "2": 163,
#         "1": 82,
#         "5": 5,
#         "4": 5
#     },
#     "zerodoom": {
#         "2": 159,
#         "1": 67,
#         "4": 4,
#         "5": 3
#     }
# }
