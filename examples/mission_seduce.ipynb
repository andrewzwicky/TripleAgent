# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.constants.paths import REPLAY_PICKLE_FOLDER
from triple_agent.constants.events import select_scl5_regular_season
from triple_agent.reports.specific.seduce import first_flirt_timing

# %%
scl5_replays = get_parsed_replays(REPLAY_PICKLE_FOLDER, select_scl5_regular_season)

# %%
first_flirt_timing(scl5_replays, "SCL5 First Flirt Timing")
