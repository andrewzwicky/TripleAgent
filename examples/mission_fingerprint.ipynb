# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.reports.generation.plot_specs import AxisProperties, DataQueryProperties
from triple_agent.constants.events import SCL5_DIVISIONS, select_scl5
from triple_agent.reports.specific.fingerprints import attempted_fingerprint_sources

# %%
scl5_replays = get_parsed_replays(select_scl5)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Object", savefig='example_pictures/scl5_fingerprints.png')
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-908235eb1f78> in <module>
#       1 attempted_fingerprint_sources(
#       2     scl5_replays,
# ----> 3     axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Object", savefig='example_pictures/scl5_fingerprints.png')
#       4 )
#
# ~\Workspace\TripleAgent\triple_agent\reports\specific\fingerprints.py in attempted_fingerprint_sources(games, data_query, axis_properties)
#      72     )
#      73
# ---> 74     query(games, data_query, axis_properties)
#
# ~\Workspace\TripleAgent\triple_agent\reports\generation\generic_query.py in query(games, data_query, axis_properties)
#      33     """
#      34     axis_properties, data_props = populate_data_properties(
# ---> 35         games, data_query, axis_properties
#      36     )
#      37
#
# ~\Workspace\TripleAgent\triple_agent\reports\generation\generic_query.py in populate_data_properties(games, data_query, axis_properties)
#      62         data_query.query_function,
#      63         data_query.groupby,
# ---> 64         data_query.percent_normalized_data,
#      65     )
#      66
#
# ~\Workspace\TripleAgent\triple_agent\reports\generation\plot_utilities.py in create_data_dictionary(games, query_function, groupby, percent_normalized_data)
#     108     if groupby is None:
#     109         data_dictionary = populate_individual_counter(
# --> 110             games, Counter(), query_function, percent_normalized_data
#     111         )
#     112
#
# ~\Workspace\TripleAgent\triple_agent\reports\generation\plot_utilities.py in populate_individual_counter(games, data_dictionary, query_function, percent_normalized_data)
#     130     games, data_dictionary, query_function, percent_normalized_data: bool = False
#     131 ):
# --> 132     query_function(games, data_dictionary)
#     133
#     134     if percent_normalized_data:
#
# TypeError: 'NoneType' object is not callable

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Division"),
    data_query=DataQueryProperties(groupby=lambda g: g.division, category_name_order=lambda g: SCL5_DIVISIONS.index(g))
)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Venue"),
    data_query=DataQueryProperties(groupby=lambda g: g.venue,)
)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
