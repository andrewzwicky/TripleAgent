# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.reports.generation.plot_specs import AxisProperties, DataQueryProperties
from triple_agent.constants.events import SCL5_DIVISIONS, select_scl5
from triple_agent.reports.specific.fingerprints import attempted_fingerprint_sources

# %%
scl5_replays = get_parsed_replays(select_scl5)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(
        title="SCL5 Fingerprint Attempts by Object",
        savefig='example_pictures/scl5_fingerprints.png')
)
# Out:
# DataPlotProperties(frame=     (TimelineCategory.Briefcase, True)  (TimelineCategory.Briefcase, False)  \
# NaN                                 120                                  658
#
#      (TimelineCategory.Statues, True)  (TimelineCategory.Statues, False)  \
# NaN                                60                                404
#
#      (TimelineCategory.Books, True)  (TimelineCategory.Books, False)  \
# NaN                             172                              371
#
#      (TimelineCategory.Drinks, True)  (TimelineCategory.Drinks, False)
# NaN                              111                               191  , stacks_are_categories=True)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Division"),
    data_query=DataQueryProperties(
        groupby=lambda g: g.division,
        secondary_order=lambda name_series: SCL5_DIVISIONS.index(name_series[0])
    )
)
# Out:
# DataPlotProperties(frame=                                     Diamond  Platinum  Gold  Silver  Bronze  \
# (TimelineCategory.Briefcase, True)        11        11     7      10      16
# (TimelineCategory.Briefcase, False)       60        48    50      95      78
# (TimelineCategory.Statues, True)           7         9     8       8      10
# (TimelineCategory.Statues, False)         26        41    26      44      53
# (TimelineCategory.Books, True)            17        17    10      24      37
# (TimelineCategory.Books, False)           32        38    42      26      48
# (TimelineCategory.Drinks, True)            8         5     6      17      21
# (TimelineCategory.Drinks, False)          15        16    18      25      31
#
#                                      Copper  Iron  Obsidian  Oak  Challenger
# (TimelineCategory.Briefcase, True)       14    19        10    9          13
# (TimelineCategory.Briefcase, False)      82    83        43   41          78
# (TimelineCategory.Statues, True)          7     3         1    2           5
# (TimelineCategory.Statues, False)        63    53        22   26          50
# (TimelineCategory.Books, True)           15    12        10   13          17
# (TimelineCategory.Books, False)          39    39        25   34          48
# (TimelineCategory.Drinks, True)          15    19         3    7          10
# (TimelineCategory.Drinks, False)         30    22         5   10          19  , stacks_are_categories=False)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Venue"),
    data_query=DataQueryProperties(groupby=lambda g: g.venue,)
)
# Out:
# DataPlotProperties(frame=                                     Aquarium  Balcony  Ballroom  Courtyard  \
# (TimelineCategory.Briefcase, True)          7        0        24         10
# (TimelineCategory.Briefcase, False)        38        1       102         97
# (TimelineCategory.Statues, True)            5        0         5         14
# (TimelineCategory.Statues, False)          30        0        60         62
# (TimelineCategory.Books, True)              9        0        27          0
# (TimelineCategory.Books, False)            27        0        66          0
# (TimelineCategory.Drinks, True)            13        1         9          9
# (TimelineCategory.Drinks, False)           19        1        19         28
#
#                                      Gallery  High-Rise  Library  Moderne  \
# (TimelineCategory.Briefcase, True)        13         11       25        8
# (TimelineCategory.Briefcase, False)       78         33       97       82
# (TimelineCategory.Statues, True)           6          2        5       11
# (TimelineCategory.Statues, False)         50         24       53       44
# (TimelineCategory.Books, True)            30         13       39       25
# (TimelineCategory.Books, False)           49         27       83       57
# (TimelineCategory.Drinks, True)            4         16        7       23
# (TimelineCategory.Drinks, False)          12         19       16       34
#
#                                      Pub  Teien  Terrace  Veranda
# (TimelineCategory.Briefcase, True)     6      4        2       10
# (TimelineCategory.Briefcase, False)   32     37       31       30
# (TimelineCategory.Statues, True)       1      1        5        5
# (TimelineCategory.Statues, False)     12     16       16       37
# (TimelineCategory.Books, True)         0      9        0       20
# (TimelineCategory.Books, False)        0     26        0       36
# (TimelineCategory.Drinks, True)       13      1       13        2
# (TimelineCategory.Drinks, False)      18      6       16        3  , stacks_are_categories=False)
