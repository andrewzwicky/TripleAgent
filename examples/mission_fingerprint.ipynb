# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.reports.generation.plot_specs import AxisProperties, DataQueryProperties
from triple_agent.constants.events import SCL5_DIVISIONS, select_scl5_regular_season
from triple_agent.reports.specific.fingerprints import attempted_fingerprint_sources

# %%
scl5_replays = get_parsed_replays(select_scl5_regular_season)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(
        title="SCL5 Fingerprint Attempts by Object",
        savefig='example_pictures/scl5_fingerprints.png')
)
# Out:
# DataPlotProperties(frame=     (TimelineCategory.Briefcase, True)  (TimelineCategory.Briefcase, False)  \
# NaN                                 128                                  693
#
#      (TimelineCategory.Statues, True)  (TimelineCategory.Statues, False)  \
# NaN                                63                                424
#
#      (TimelineCategory.Books, True)  (TimelineCategory.Books, False)  \
# NaN                             179                              397
#
#      (TimelineCategory.Drinks, True)  (TimelineCategory.Drinks, False)
# NaN                              120                               205  , stacks_are_categories=True)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Division"),
    data_query=DataQueryProperties(
        groupby=lambda g: g.division,
        secondary_order=lambda name_series: SCL5_DIVISIONS.index(name_series[0])
    )
)
# Out:
# DataPlotProperties(frame=                                     Diamond  Platinum  Gold  Silver  Bronze  \
# (TimelineCategory.Briefcase, True)        11        11     7      10      16
# (TimelineCategory.Briefcase, False)       60        49    50      95      84
# (TimelineCategory.Statues, True)           7         9     8       8      10
# (TimelineCategory.Statues, False)         26        42    26      44      55
# (TimelineCategory.Books, True)            17        18    10      24      37
# (TimelineCategory.Books, False)           32        38    42      26      53
# (TimelineCategory.Drinks, True)            8         7     6      17      22
# (TimelineCategory.Drinks, False)          15        19    18      25      33
#
#                                      Copper  Iron  Obsidian  Oak  Challenger
# (TimelineCategory.Briefcase, True)       14    19        10   11          19
# (TimelineCategory.Briefcase, False)      82    83        45   50          95
# (TimelineCategory.Statues, True)          7     3         1    3           7
# (TimelineCategory.Statues, False)        63    53        22   35          58
# (TimelineCategory.Books, True)           15    12        10   15          21
# (TimelineCategory.Books, False)          39    39        28   45          55
# (TimelineCategory.Drinks, True)          15    19         3    8          15
# (TimelineCategory.Drinks, False)         30    22         6   10          27  , stacks_are_categories=False)

# %%
attempted_fingerprint_sources(
    scl5_replays, 
    axis_properties=AxisProperties(title="SCL5 Fingerprint Attempts by Venue"),
    data_query=DataQueryProperties(groupby=lambda g: g.venue,)
)
# Out:
# DataPlotProperties(frame=                                     Aquarium  Balcony  Ballroom  Courtyard  \
# (TimelineCategory.Briefcase, True)          7        0        24         14
# (TimelineCategory.Briefcase, False)        40        1       105        102
# (TimelineCategory.Statues, True)            5        0         5         14
# (TimelineCategory.Statues, False)          30        0        61         65
# (TimelineCategory.Books, True)              9        0        29          0
# (TimelineCategory.Books, False)            29        0        68          0
# (TimelineCategory.Drinks, True)            13        1         9          9
# (TimelineCategory.Drinks, False)           19        1        20         30
#
#                                      Gallery  High-Rise  Library  Moderne  \
# (TimelineCategory.Briefcase, True)        13         11       26        9
# (TimelineCategory.Briefcase, False)       82         35      102       84
# (TimelineCategory.Statues, True)           7          2        5       12
# (TimelineCategory.Statues, False)         52         24       55       47
# (TimelineCategory.Books, True)            32         13       40       25
# (TimelineCategory.Books, False)           50         28       86       63
# (TimelineCategory.Drinks, True)            5         17        7       25
# (TimelineCategory.Drinks, False)          13         19       17       36
#
#                                      Pub  Teien  Terrace  Veranda
# (TimelineCategory.Briefcase, True)     7      4        3       10
# (TimelineCategory.Briefcase, False)   38     39       33       32
# (TimelineCategory.Statues, True)       1      1        6        5
# (TimelineCategory.Statues, False)     15     19       17       39
# (TimelineCategory.Books, True)         0     11        0       20
# (TimelineCategory.Books, False)        0     31        0       42
# (TimelineCategory.Drinks, True)       18      1       13        2
# (TimelineCategory.Drinks, False)      23      6       18        3  , stacks_are_categories=False)
