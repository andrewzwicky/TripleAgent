# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
project_path = str(Path().joinpath('..', 'triple_agent').resolve())
sys.path.append(project_path)
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.replays.get_parsed_replays import get_parsed_replays
from triple_agent.utilities.event_constants import SCL5_DIVISIONS, select_scl5
from triple_agent.reports.fingerprints import attempted_fingerprint_sources

# %%
scl5_replays = get_parsed_replays(select_scl5)

# %%
attempted_fingerprint_sources(scl5_replays, "SCL5 Fingerprint Attempts by Object", savefig='example_pictures/scl5_fingerprints.png')

# %%
attempted_fingerprint_sources(
    scl5_replays,
    "SCL5 Fingerprint Attempts by Division",
    groupby=lambda g: g.division,
    category_name_order=lambda g: SCL5_DIVISIONS.index(g)
)

# %%
attempted_fingerprint_sources(
    scl5_replays,
    "SCL5 Fingerprint Attempts by Venue",
    groupby=lambda g: g.venue,
)
