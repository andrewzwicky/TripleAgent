# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.constants.events import SCL5_DIVISIONS, select_scl5_regular_season
from triple_agent.reports.specific.mission_progress import mission_progress
from triple_agent.classes.outcomes import WinType

# %%
scl5_replays = get_parsed_replays(select_scl5_regular_season)

# %%
mission_progress(scl5_replays,'SCL5 Mission Progress')

# %%
mission_progress(
    filter(lambda g: g.win_type == WinType.MissionsWin, scl5_replays),
    'SCL5 Mission Progress [Missions Win]'
)

# %%
mission_progress(
    filter(lambda g: g.win_type == WinType.SpyShot, scl5_replays),
    'SCL5 Mission Progress [Spy Shot]'
)

# %%
mission_progress(
    filter(lambda g: g.win_type == WinType.TimeOut, scl5_replays),
    'SCL5 Mission Progress [TimeOut]'
)

# %%
mission_progress(
    filter(lambda g: g.win_type == WinType.CivilianShot, scl5_replays),
    'SCL5 Mission Progress [Civilian Shot]'
)
