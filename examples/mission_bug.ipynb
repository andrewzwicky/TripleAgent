# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.reports.generation.plot_specs import AxisProperties, DataQueryProperties
from triple_agent.constants.events import SCL5_DIVISIONS, select_scl5
from triple_agent.reports.specific.bug import bug_attempt_timings, bug_success_rate

# %%
scl5_replays = get_parsed_replays(select_scl5)

# %%
bug_success_rate(
    scl5_replays,
    axis_properties=AxisProperties(title="SCL5 Bug Success Rates"),
)
# Out:
# DataPlotProperties(frame=     (Walking, True)  (Walking, False)  (Standing, True)  (Standing, False)
# NaN             1175               802               260                  3, stacks_are_categories=True)

# %%
bug_success_rate(
    scl5_replays,
    axis_properties=AxisProperties(title='SCL5 Bug Success Rates by Division'),
    data_query=DataQueryProperties(
        groupby=lambda g: g.division,
        secondary_order=lambda name_series: SCL5_DIVISIONS.index(name_series[0]))
)
# Out:
# DataPlotProperties(frame=                   Diamond  Platinum  Gold  Silver  Bronze  Copper  Iron  \
# (Walking, True)         84       122    80     142     123     145   180
# (Walking, False)        46        53    70      79      84      83   153
# (Standing, True)        34        23    20      36      17      31    31
# (Standing, False)        1         0     0       1       1       0     0
#
#                    Obsidian  Oak  Challenger
# (Walking, True)          61   78         160
# (Walking, False)         47   58         129
# (Standing, True)         18   15          35
# (Standing, False)         0    0           0  , stacks_are_categories=False)

# %%
bug_attempt_timings(scl5_replays, "SCL5 Bug Attempt Timings")
