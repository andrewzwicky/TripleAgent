# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.constants.events import select_scl5
from triple_agent.reports.specific.time_adds import time_add_times, time_add_times_per_game

# %%
scl5_replays = get_parsed_replays(select_scl5)

# %%
time_add_times(scl5_replays, "Time Add Attempts per Game")

# %%
time_add_times_per_game(scl5_replays, "SCL5 Time Adds", force_bar=True, category_name_order=lambda s: s)

# %%
time_add_times_per_game(scl5_replays, "SCL5 Time Adds by Venue", groupby=lambda g: g.venue)
