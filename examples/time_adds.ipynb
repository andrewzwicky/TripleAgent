# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
parent_path = str(Path().joinpath('..').resolve())
sys.path.append(parent_path)

# %%
from triple_agent.parsing.replay.get_parsed_replays import get_parsed_replays
from triple_agent.reports.generation.plot_specs import AxisProperties, DataQueryProperties
from triple_agent.constants.events import select_scl5_regular_season
from triple_agent.reports.specific.time_adds import time_add_times, time_add_times_per_game

# %%
scl5_replays = get_parsed_replays(select_scl5_regular_season)

# %%
time_add_times(scl5_replays, "Time Add Attempts per Game")

# %%
time_add_times_per_game(
    scl5_replays,
    axis_properties=AxisProperties(title="SCL5 Time Adds In Game", force_bar=True),
    data_query=DataQueryProperties(primary_order=lambda name_series: name_series[0])
)
# Out:
# DataPlotProperties(frame=        0    1   2   3  4  5  8
# NaN  3560  573  62  10  5  1  1, stacks_are_categories=True)

# %%
time_add_times_per_game(
    scl5_replays,
    axis_properties=AxisProperties(title="SCL5 Time Adds In Game", force_bar=True),
    data_query=DataQueryProperties(groupby=lambda g: g.venue)
)
# Out:
# DataPlotProperties(frame=   Aquarium  Balcony  Ballroom  Courtyard  Gallery  High-Rise  Library  \
# 8         1        0         0          0        0          0        0
# 5         0        0         0          0        0          0        1
# 4         0        0         0          0        1          0        4
# 3         0        0         0          0        1          0        5
# 2         2        0         3         11        8          0       18
# 1        20       10        56         74       82         12      122
# 0       190      277       484        458      325        280      390
#
#    Moderne  Pub  Teien  Terrace  Veranda
# 8        0    0      0        0        0
# 5        0    0      0        0        0
# 4        0    0      0        0        0
# 3        1    0      1        0        2
# 2       10    0      1        0        9
# 1       59   43     22       10       63
# 0      328  275    179      241      133  , stacks_are_categories=False)
